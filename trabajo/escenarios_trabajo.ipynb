# %%
##Estimación de indicadores de trabajo
#Se borra todo lo que se encuentra en el entorno

rm(list=ls())

# Librerías ====
if(!require('pacman')) install.packages('pacman')
pacman::p_load(tidyverse,lubridate, showtext,srvyr,foreign,zoo)
font_add_google("Poppins", "pop")
showtext_auto()
remotes::install_github("cpyp-ipdp/funcionespgd", force = TRUE)
library(funcionespgd)
# Out:
# Cargando paquete requerido: pacman
#
# Using GitHub PAT from the git credential store.
#
# ...
# rlang    (1.1.4 -> 1.1.6) [CRAN]
# glue     (1.7.0 -> 1.8.0) [CRAN]
# cli      (3.6.3 -> 3.6.5) [CRAN]
# magrittr (2.0.3 -> 2.0.4) [CRAN]
# tibble   (3.2.1 -> 3.3.0) [CRAN]
# ggplot2  (3.5.2 -> 4.0.0) [CRAN]
# Installing 6 packages: rlang, glue, cli, magrittr, tibble, ggplot2
#
# Warning message:
# "packages 'tibble', 'ggplot2' are in use and will not be installed"
# Installing packages into 'C:/Users/claud/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problema al copiar C:\Users\claud\AppData\Local\R\win-library\4.4\00LOCK\rlang\libs\x64\rlang.dll  a C:\Users\claud\AppData\Local\R\win-library\4.4\rlang\libs\x64\rlang.dll: Permission denied"
# Warning message:
# ...

# %%
## leer excel
informalidad <- openxlsx::read.xlsx("datos_indicadorestrabajo_20250530.xlsx", sheet="informalidad")%>%
  
rename(
  year = periodo,
  estimado = tendencia_deseable,
  superior = tendencia_inercial,
  inferior=tendencia_disruptivo

)%>%
mutate(
    year = as.yearqtr(gsub("-", " Q", year), format = "%Y Q%q")
  )%>%
  #Eliminar todos los valores de 2045 excepto el del 4to trimestre
  filter(!(year == as.yearqtr("2045 Q1") | year == as.yearqtr("2045 Q2") | year == as.yearqtr("2045 Q3") | 
  year == as.yearqtr("2024 Q1") | year == as.yearqtr("2024 Q2") | year == as.yearqtr("2024 Q4")))%>%
  #Cambiar etiqueta a 2045 Q4 a Q1
  mutate(
    year = ifelse(year == as.yearqtr("2045 Q4"), as.yearqtr("2045 Q1"), year),
    year = ifelse(year == as.yearqtr("2024 Q3"), as.yearqtr("2024 Q1"), year),
    year = as.yearqtr(year)
  )
informalidad
# Out:
#     year    superior estimado inferior
# 1   2005 Q1 49.4     49.4     49.4
# 2   2005 Q2 49.7     49.7     49.7
# 3   2005 Q3 50.4     50.4     50.4
# 4   2005 Q4 51.6     51.6     51.6
# 5   2006 Q1 50.5     50.5     50.5
# 6   2006 Q2 51.4     51.4     51.4
# 7   2006 Q3 49.3     49.3     49.3
# 8   2006 Q4 47.2     47.2     47.2
# 9   2007 Q1 47.9     47.9     47.9
# 10  2007 Q2 48.0     48.0     48.0
# 11  2007 Q3 47.0     47.0     47.0
# 12  2007 Q4 48.6     48.6     48.6
# 13  2008 Q1 47.1     47.1     47.1
# 14  2008 Q2 49.4     49.4     49.4
# 15  2008 Q3 47.2     47.2     47.2
# 16  2008 Q4 47.9     47.9     47.9
# 17  2009 Q1 47.3     47.3     47.3
# 18  2009 Q2 50.2     50.2     50.2
# 19  2009 Q3 48.2     48.2     48.2
# 20  2009 Q4 49.1     49.1     49.1
# 21  2010 Q1 49.5     49.5     49.5
# 22  2010 Q2 48.9     48.9     48.9
# 23  2010 Q3 48.7     48.7     48.7
# 24  2010 Q4 48.5     48.5     48.5
# 25  2011 Q1 48.9     48.9     48.9
# ...

# %%
grafica_bonita(
  data = informalidad,
  x = "year",
  y = "estimado",
  titulo = "Tasa de informalidad laboral",
      ano_base = 2024,
  mostrar_etiqueta_ano_base = TRUE,
  linea_vertical = 2024,
  anios_etiquetas = c(2045),
    desplazamiento_ano_base=c(0.8, 0.4),
  mostrar_intervalo = "ambos",
  nombre_observado = "Observado",
  nombre_estimado_futuro = "Deseable",
  nombre_intervalo_superior = "Inercial",
  nombre_intervalo_inferior = "Transformador",
  mostrar_leyenda = TRUE,
  fuente = "pop",
  etiqueta_x = "Año",
  etiqueta_y = "Tasa",
  titulo_leyenda = "Escenarios",
  limite_inferior_y = 20
)

ggsave("H:/Mi unidad/pgd/graficas/Línea 19. De Trabajo Digno y Capacidades Humanas Fortalecidas/informalidad_estimada.png", width = 12, height = 6, dpi = 185, bg = "white")
# Out:
# plot without title

# %%
tcco <- openxlsx::read.xlsx("datos_indicadorestrabajo_20250530.xlsx", sheet="tcco")%>%
  
rename(
  year = periodo,
  estimado = tendencia_deseable,
  superior = tendencia_inercial,
  inferior=tendencia_disruptivo

)%>%
mutate(
    year = as.yearqtr(gsub("-", " Q", year), format = "%Y Q%q")
  )%>%
    #Eliminar todos los valores de 2045 excepto el del 4to trimestre
  filter(!(year == as.yearqtr("2045 Q1") | year == as.yearqtr("2045 Q2") | year == as.yearqtr("2045 Q3") | 
  year == as.yearqtr("2024 Q1") | year == as.yearqtr("2024 Q2") | year == as.yearqtr("2024 Q4")))%>%
  #Cambiar etiqueta a 2045 Q4 a Q1
  mutate(
    year = ifelse(year == as.yearqtr("2045 Q4"), as.yearqtr("2045 Q1"), year),
    year = ifelse(year == as.yearqtr("2024 Q3"), as.yearqtr("2024 Q1"), year),
    year = as.yearqtr(year)
  )
tcco
# Out:
#     year    superior estimado inferior
# 1   2005 Q1  9.9      9.9      9.9
# 2   2005 Q2  9.6      9.6      9.6
# 3   2005 Q3  9.6      9.6      9.6
# 4   2005 Q4  9.0      9.0      9.0
# 5   2006 Q1  8.2      8.2      8.2
# 6   2006 Q2  7.1      7.1      7.1
# 7   2006 Q3  7.4      7.4      7.4
# 8   2006 Q4  7.3      7.3      7.3
# 9   2007 Q1  7.9      7.9      7.9
# 10  2007 Q2  7.6      7.6      7.6
# 11  2007 Q3  8.8      8.8      8.8
# 12  2007 Q4  7.8      7.8      7.8
# 13  2008 Q1  6.6      6.6      6.6
# 14  2008 Q2  8.4      8.4      8.4
# 15  2008 Q3  8.1      8.1      8.1
# 16  2008 Q4  9.2      9.2      9.2
# 17  2009 Q1  7.9      7.9      7.9
# 18  2009 Q2  9.9      9.9      9.9
# 19  2009 Q3  9.0      9.0      9.0
# 20  2009 Q4  8.5      8.5      8.5
# 21  2010 Q1  9.9      9.9      9.9
# 22  2010 Q2  9.4      9.4      9.4
# 23  2010 Q3  9.3      9.3      9.3
# 24  2010 Q4 10.6     10.6     10.6
# 25  2011 Q1 10.3     10.3     10.3
# ...

# %%
grafica_bonita(
  data = tcco,
  x = "year",
  y = "estimado",
  titulo = "Tasa de condiciones críticas de ocupación",
        ano_base = 2024,
  mostrar_etiqueta_ano_base = TRUE,
  linea_vertical = 2024,
  anios_etiquetas = c(2045),
    desplazamiento_ano_base=c(1, 2),
  mostrar_intervalo = "ambos",
  nombre_observado = "Observado",
  nombre_estimado_futuro = "Deseable",
  nombre_intervalo_superior = "Inercial",
  nombre_intervalo_inferior = "Transformador",
  mostrar_leyenda = TRUE,
  fuente = "pop",
  etiqueta_x = "Año",
  etiqueta_y = "Tasa",
  titulo_leyenda = "Escenarios",
  limite_inferior_y = 5
)

ggsave("H:/Mi unidad/pgd/graficas/Línea 19. De Trabajo Digno y Capacidades Humanas Fortalecidas/tcco_estimada.png", width = 10, height = 6, dpi = 250, bg = "white")
# Out:
# plot without title

# %%
partfem <- openxlsx::read.xlsx("datos_indicadorestrabajo_20250530.xlsx", sheet="tasa_part_fem")%>%
  
rename(
  year = periodo,
  estimado = tendencia_deseable,
  superior = tendencia_inercial,
  inferior=tendencia_disruptivo

)%>%
mutate(
    year = as.yearqtr(gsub("-", " Q", year), format = "%Y Q%q")
  )%>%
    #Eliminar todos los valores de 2045 excepto el del 4to trimestre
  filter(!(year == as.yearqtr("2045 Q1") | year == as.yearqtr("2045 Q2") | year == as.yearqtr("2045 Q3") | 
  year == as.yearqtr("2024 Q1") | year == as.yearqtr("2024 Q2") | year == as.yearqtr("2024 Q4")))%>%
  #Cambiar etiqueta a 2045 Q4 a Q1
  mutate(
    year = ifelse(year == as.yearqtr("2045 Q4"), as.yearqtr("2045 Q1"), year),
    year = ifelse(year == as.yearqtr("2024 Q3"), as.yearqtr("2024 Q1"), year),
    year = as.yearqtr(year)
  )
partfem
# Out:
#     year    superior estimado inferior
# 1   2005 Q1 44.9     44.9     44.9
# 2   2005 Q2 46.1     46.1     46.1
# 3   2005 Q3 46.4     46.4     46.4
# 4   2005 Q4 48.0     48.0     48.0
# 5   2006 Q1 48.0     48.0     48.0
# 6   2006 Q2 47.9     47.9     47.9
# 7   2006 Q3 49.8     49.8     49.8
# 8   2006 Q4 50.0     50.0     50.0
# 9   2007 Q1 49.6     49.6     49.6
# 10  2007 Q2 48.2     48.2     48.2
# 11  2007 Q3 48.9     48.9     48.9
# 12  2007 Q4 50.0     50.0     50.0
# 13  2008 Q1 48.2     48.2     48.2
# 14  2008 Q2 49.5     49.5     49.5
# 15  2008 Q3 47.9     47.9     47.9
# 16  2008 Q4 47.0     47.0     47.0
# 17  2009 Q1 48.2     48.2     48.2
# 18  2009 Q2 48.6     48.6     48.6
# 19  2009 Q3 50.6     50.6     50.6
# 20  2009 Q4 48.1     48.1     48.1
# 21  2010 Q1 47.7     47.7     47.7
# 22  2010 Q2 48.5     48.5     48.5
# 23  2010 Q3 49.2     49.2     49.2
# 24  2010 Q4 48.4     48.4     48.4
# 25  2011 Q1 47.6     47.6     47.6
# ...

# %%
grafica_bonita(
  data = partfem,
  x = "year",
  y = "estimado",
  titulo = "Tasa de participación económica de las mujeres",
          ano_base = 2024,
  mostrar_etiqueta_ano_base = TRUE,
  linea_vertical = 2024,
  anios_etiquetas = c(2045),
    desplazamiento_ano_base=c(0.8, 0.4),
  mostrar_intervalo = "ambos",
  nombre_observado = "Observado",
  nombre_estimado_futuro = "Deseable",
  nombre_intervalo_superior = "Inercial",
  nombre_intervalo_inferior = "Transformador",
  mostrar_leyenda = TRUE,
  fuente = "pop",
  etiqueta_x = "Año",
  etiqueta_y = "Tasa",
  titulo_leyenda = "Escenarios",
  limite_inferior_y = 30
)

ggsave("H:/Mi unidad/pgd/graficas/Línea 19. De Trabajo Digno y Capacidades Humanas Fortalecidas/tpartfem_estimada.png", width = 10, height = 8, dpi = 185, bg = "white")
# Out:
# plot without title

# %%
prod <- openxlsx::read.xlsx("datos_indicadorestrabajo_20250530.xlsx", sheet="productividad")%>%
  
rename(
  year = periodo,
  estimado = tendencia_deseable,
  superior = tendencia_inercial,
  inferior=tendencia_disruptivo
  )
prod
# Out:
#    year superior  estimado  inferior
# 1  2005  90.76008  90.76008  90.76008
# 2  2006  92.81775  92.81775  92.81775
# 3  2007  95.22517  95.22517  95.22517
# 4  2008  96.45228  96.45228  96.45228
# 5  2009  91.84219  91.84219  91.84219
# 6  2010  95.28200  95.28200  95.28200
# 7  2011  96.74175  96.74175  96.74175
# 8  2012  96.21962  96.21962  96.21962
# 9  2013  96.79505  96.79505  96.79505
# 10 2014  99.89514  99.89514  99.89514
# 11 2015  99.13948  99.13948  99.13948
# 12 2016 100.12765 100.12765 100.12765
# 13 2017 101.85295 101.85295 101.85295
# 14 2018 100.00000 100.00000 100.00000
# 15 2019  98.29626  98.29626  98.29626
# 16 2020  99.68744  99.68744  99.68744
# 17 2021  99.74553  99.74553  99.74553
# 18 2022  96.33471  96.33471  96.33471
# 19 2023  97.20844  97.20844  97.20844
# 20 2024  96.94562  97.47161  97.60320
# 21 2025  96.68351  97.73550  97.99956
# 22 2026  96.42211  98.00010  98.39753
# 23 2027  96.16142  98.26541  98.79712
# 24 2028  95.90143  98.53145  99.19833
# ...

# %%
grafica_bonita(
  data = prod,
  x = "year",
  y = "estimado",
  titulo = "Indicador de Productividad Laboral",
            ano_base = 2023,
  mostrar_etiqueta_ano_base = TRUE,
  linea_vertical = 2023,
  anios_etiquetas = c(2045),
    desplazamiento_ano_base=c(0.9, 1.2),
  mostrar_intervalo = "ambos",
  nombre_observado = "Observado",
  nombre_estimado_futuro = "Deseable",
  nombre_intervalo_superior = "Inercial",
  nombre_intervalo_inferior = "Transformador",
  mostrar_leyenda = TRUE,
  fuente = "pop",
  etiqueta_x = "Año",
  etiqueta_y = "Índice",
  titulo_leyenda = "Escenarios",
  limite_inferior_y = 85
)

ggsave("H:/Mi unidad/pgd/graficas/Línea 19. De Trabajo Digno y Capacidades Humanas Fortalecidas/prod_estimada.png", width = 10, height = 8, dpi = 185, bg = "white")
# Out:
# plot without title
